# %%
from __future__ import division, print_function # python3 compatibilty
import pymc3 as pm
import numpy
import pandas as pd
import numpy as np                  # import numpy
from time import time               # use for timing functions
import matplotlib.gridspec as gridspec
from scipy import stats
#from matplotlib import pyplot as pl # import pyplot from matplotlib
import matplotlib.pyplot as plt

rcparams = {}
rcparams['text.usetex'] = True
rcparams['axes.linewidth'] = 0.7
rcparams['font.family'] = 'sans-serif'
rcparams['font.size'] = 22

from matplotlib import rc
plt.rcParams['axes.xmargin'] = 0
plt.rcParams['axes.ymargin'] = 0
plt.rcParams['mathtext.fontset'] = 'dejavuserif'
from sklearn.metrics import mean_squared_error, r2_score
import arviz as az

# functions for plotting posteriors
import scipy
import corner
from scipy.stats import gaussian_kde
import os

# %%
#read the data
os.chdir('/Users/krishna/Documents/phd_work/SNe_data_analy/checks')

df = pd.read_csv('data_sbf_new.csv')
SN_sbf = df['SN_name'].to_numpy()
host = df['host'].to_numpy()
mu_sbf = df['mu_SBF'].to_numpy()
e_mu = df['e_mu'].to_numpy()
bmax = df['Bmax'].to_numpy()
ebmax = df['eBmax'].to_numpy()
vmax = df['Vmax'].to_numpy()
evmax = df['eVmax'].to_numpy()
st = df['stretch'].to_numpy()
est = df['err_stretch'].to_numpy()
color = df['color'].to_numpy()
ecolor = df ['e_color'].to_numpy()
log_M = df['log_Mass'].to_numpy()
e_logM = df['e_logMass'].to_numpy()

#display(df)
print(len(SN_sbf))

#Lowzhflow_maxmodel_st

dff = pd.read_csv('data_lowz_HM.csv')
#df_cos = pd.read_csv('data_lowz_HM.csv')
df_cos = dff.loc[(dff['redshift'] > 0.02) & (dff['redshift'] < 0.15)]
#df_cos = dfff.loc[(dfff['stretch'] > 0.5) & (dfff['color'] < 0.3)]
SN_name = df_cos['SN_name'].to_numpy()
Bmax = df_cos['Bmax'].to_numpy()
eBmax = df_cos['eBmax'].to_numpy()
Vmax = df_cos['Vmax'].to_numpy()
eVmax = df_cos['eVmax'].to_numpy()
s = df_cos['stretch'].to_numpy()
es = df_cos['err_stretch'].to_numpy()
ebv = df_cos['color'].to_numpy()
eEBV = df_cos['e_color'].to_numpy()
# logM = df_cos['log_Mass'].to_numpy()
# elogM = df_cos['e_logMass'].to_numpy()
z = df_cos['redshift'].to_numpy()

print(len(z))
# Out:
# 26
# 96

# %%
with pm.Model():
    #priors
    P_0 = pm.Uniform('P0', lower = -30, upper = 30)
    P_1 = pm.Uniform('P1', lower = -5, upper = 5)
    R = pm.Uniform('R', lower = 0, upper = 15)
    H0 = pm.Uniform('H0', lower = 60, upper = 80)
    sigma_calib = pm.HalfCauchy('sigcal', 5)
    sigma_cosmo =  pm.HalfCauchy('sigcos', 5)
    
    c = 299792.458
    q0 = -0.55
    j0 = 1
    
    #model
    mu0 = P_0 + P_1*(st-1) + R*(color) + mu_sbf
    
    mu1 = P_0 + P_1*(s-1) + R*(ebv) + 5*np.log10((c*z/H0)*(1 + 1/2*(1- q0)*z - 1/6*(1- q0 - 3*q0**2 + j0)*z**2)) + 25
  
    #sigma
    sigma0 = np.sqrt(ebmax ** 2 + sigma_calib**2 + e_mu**2 + (P_1*est)**2 +
                    R**2*(ebmax**2 + evmax**2) - 2*R*ebmax**2)
    
    sigma1 = np.sqrt(eBmax ** 2 + sigma_cosmo**2 + (P_1*es)**2 +
                    R**2*(eBmax**2 + eVmax**2) - 2*R*eBmax**2)
    
    # This line is constructing the likelihood for me taking data, model, and sigma
    results0 = pm.Normal('results0', mu0, sigma0, observed = bmax)
    results1 = pm.Normal('results1', mu1, sigma1, observed = Bmax)
   
    
    
    Nsamples = 3000  # final number of samples
    Ntune = 3000  # number of tuning samples

    # perform sampling
    t0 = time()
    trace = pm.sample(Nsamples, tune=Ntune, discard_tuned_samples=True, cores=4,target_accept=0.9);  # perform sampling
    t1 = time()
    timepymc3 = (t1-t0)
    print("Time taken to run 'PyMC3' is {} seconds".format(timepymc3))
    plt.rcParams.update({'font.size': 12})
    #pm.traceplot(trace) 
    print(pm.summary(trace))
#------------------------------------------------------------------------
#Function to plot corner plots
    
def plotposts(samples):    
    fig = corner.corner(samples, bins = 50, labels=[r'$P_0$', r'$P_1$', r'$R$', r'$H_0$', r'$\sigma_{calib}$', r'$\sigma_{cosmo}$'], 
                        color = 'black',
                        show_titles=True,
                        hist_kwargs={'density': True}, smooth = True, title_kwargs={"fontsize": 14},
                        label_kwargs={"fontsize": 14})


        # plot KDE smoothed version of distributions
    for axidx, samps in zip([0, 7, 14, 21, 28, 35], samples.T):
        kde = gaussian_kde(samps)
        xvals = fig.axes[axidx].get_xlim()
        xvals = np.linspace(xvals[0], xvals[1], 100)
        fig.axes[axidx].plot(xvals, kde(xvals), color='firebrick', lw = 1)
    fig = plt.gcf() # to get the current figure...
    #fig.savefig("SBF_noHM_corner_18thJune.pdf",dpi = 500, bbox_inches='tight', pad_inches=0.2)

#plt.rcParams.update({'font.size': 16}) # reset the font size
samples_pymc3 = np.vstack((trace['P0'], trace['P1'], trace['R'], trace['H0'], trace['sigcal'], trace['sigcos'])).T
plotposts(samples_pymc3)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigcos, sigcal, H0, R, P1, P0]
# Sampling 4 chains, 0 divergences: 100%|██████████| 24000/24000 [00:53<00:00, 451.58draws/s]
# The acceptance probability does not match the target. It is 0.8351073019058559, but should be close to 0.9. Try to increase the number of tuning steps.
# Time taken to run 'PyMC3' is 64.00845098495483 seconds
#           mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_mean  ess_sd  \
# P0     -19.266  0.074 -19.401  -19.125      0.001    0.001    6229.0  6229.0
# P1      -1.059  0.118  -1.281   -0.834      0.001    0.001    8855.0  8850.0
# R        2.007  0.167   1.694    2.318      0.002    0.001    9695.0  9695.0
# H0      69.086  2.368  64.815   73.707      0.030    0.021    6411.0  6354.0
# sigcal   0.311  0.061   0.202    0.424      0.001    0.000    8807.0  8537.0
# sigcos   0.148  0.017   0.117    0.180      0.000    0.000    9893.0  9800.0
#
#         ess_bulk  ess_tail  r_hat
# P0        6356.0    6399.0    1.0
# P1        8889.0    7581.0    1.0
# R         9651.0    8128.0    1.0
# H0        6595.0    6136.0    1.0
# sigcal    9040.0    8460.0    1.0
# sigcos    9886.0    8503.0    1.0

# %%
#fit params
means = pm.summary(trace)['mean'].values
sds = pm.summary(trace)['sd'].values
p0, ep0 = means[0], sds[0]
p1, ep1 = means[1], sds[1]
r, er = means[2], sds[2]
sig_cal = means[4]
sig_cos = means[5]

# ypred = p0 + p1*(s-1) + r*(ebv) + 5*np.log10((c*z/H0)*(1 + 1/2*(1- q0)*z - 1/6*(1- q0 - 3*q0**2 + j0)*z**2)) + 25
# ytrue = Bmax
# print(pm.r2_score(ytrue, ypred))

# %%
#calculate mu
def mu_HM(st, mB, mV, P0, P1, R, est, emB, eEBV, eP0, eP1 , eR, dSN):   #alp = alpha

    mu_i = mB - P0 - P1*(st - 1.) - R*(mB-mV)    # calculate the distance modulus

    dmu_i = np.sqrt(emB ** 2 + eP0 ** 2 + ((st - 1.) * eP1) ** 2 + (P1*est)**2 + (eR * (mB - mV)) ** 2 
                + dSN ** 2 + (R*eEBV)**2) # calculate the error on \mu

    return mu_i, dmu_i

mu_SBF =[]
dmu =[]

for i in range(len(Bmax)):
    mu, sig_mu = mu_HM(s[i],Bmax[i], Vmax[i], p0, p1, r, es[i], eBmax[i], eEBV[i], ep0, ep1, er, sig_cal)
    mu_SBF.append(mu)
    dmu.append(sig_mu)
    #mu_SBF = [round(elem, 3) for elem in mu_SBF]
    #sig_muSBF = [round(elem, 3) for elem in sig_muSBF]

dict = {'name': SN_name, 'mu': mu_SBF, 'err_mu': dmu, 'redshift': z}     
dist = pd.DataFrame(dict)
#dist.to_csv(os.getcwd()+'/Hierchichal_analysis/SBF_cosmo_full.csv')

# %%
# R2 score and RMSE of the models
plt.rcParams['axes.xmargin'] = 0.01
plt.rcParams['axes.ymargin'] = 0.03
plt.rc('font', family='serif')
from sklearn.metrics import mean_squared_error, r2_score

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13,6))

#plot the relation
def bestfit(p0,p1,st):
    return p0 + p1*(st-1)

x = np.linspace(0., 1.5, 100)
fit1 = bestfit(p0, p1, x)
pred = bestfit(p0, p1, st)

Mb = []
Mb_err = []
for i in range(len(bmax)):
    M =  bmax[i] - mu_sbf[i] - r*(color[i])
    dM = np.sqrt(ebmax[i] ** 2 + e_mu[i]**2 + (r*ecolor[i])**2 + (er*color[i])**2)
    Mb.append(M)
    Mb_err.append(dM)

ax1.tick_params(axis='both',direction='in',labelsize=16)
ax1.xaxis.set_tick_params(which='major',width=1.5,length=7.5)
ax1.xaxis.set_tick_params(which='minor',width=1.5,length=4.5)
ax1.yaxis.set_tick_params(which='major',width=1.5,length=7.5)
ax1.yaxis.set_tick_params(which='minor',width=1.5,length=4.5)
ax1.spines['top'].set_linewidth(1.5)
ax1.spines['right'].set_linewidth(1.5)
ax1.spines['bottom'].set_linewidth(1.5)
ax1.spines['left'].set_linewidth(1.5)
ax1.xaxis.set_label_coords(0.5, -0.06)
ax1.tick_params(axis='both',direction='in',which='both')
plt.rc('font', family='serif')

ax1.errorbar(st , Mb , yerr = Mb_err, xerr = est, fmt = 'o', mfc = '#67a9cf', ms = 10, lw = 1.2, capsize = 5)
ax1.plot(x , fit1, color = 'black', lw = 1.8)
ax1.set_xlabel(r"$s_{BV}$", fontfamily = 'serif', fontsize = 18) 
ax1.set_ylabel(r"$m_B - \mu_{SBF} - R(m_B - m_V)$", fontfamily = 'serif', fontsize = 16)
ax1.invert_xaxis()
ax1.set_ylim(-16, -21.5)
ax1.text(0.5, -20.5, '$R^2 = 0.40$', fontfamily = 'serif', fontsize = 16)
print("Mean squared error_st: %.2f" % mean_squared_error(Mb,pred))
print("R2 Score_st: %.2f" % r2_score(Mb,pred))

def colorfit(p0 , R, col):
    return p0 + R*col

col = np.linspace(-0.2, 0.8, 100)
fit2 = colorfit(p0, r, col)
pred2 = colorfit(p0, r, color)

Mcol = []
Mcol_err = []
for i in range(len(bmax)):
    M = bmax[i] - mu_sbf[i] - p1*(st[i] - 1)
    dM = np.sqrt(ebmax[i]**2 + e_mu[i]**2 + (p1*est[i])**2 + (ep1*(st[i]-1))**2)
    Mcol.append(M)
    Mcol_err.append(dM)

ax2.tick_params(axis='both',direction='in',labelsize=16)
ax2.xaxis.set_tick_params(which='major',width=1.5,length=7.5)
ax2.xaxis.set_tick_params(which='minor',width=1.5,length=4.5)
ax2.yaxis.set_tick_params(which='major',width=1.5,length=7.5)
ax2.yaxis.set_tick_params(which='minor',width=1.5,length=4.5)
ax2.spines['top'].set_linewidth(1.5)
ax2.spines['right'].set_linewidth(1.5)
ax2.spines['bottom'].set_linewidth(1.5)
ax2.spines['left'].set_linewidth(1.5)
ax2.xaxis.set_label_coords(0.5, -0.06)
ax2.tick_params(axis='both',direction='in',which='both')


ax2.errorbar(color , Mcol, yerr = Mcol_err , xerr = ecolor, fmt = 'o', mfc = '#67a9cf', ms = 10, lw = 1.2, capsize = 5)
ax2.plot(col, fit2, color='black', lw = 1.8)
ax2.set_xlabel(r"$(m_B-m_V)$", fontfamily = 'serif', fontsize = 18) 
ax2.set_ylabel(r"$m_B - \mu_{SBF} - P^1(s_{BV} - 1)$", labelpad = 0, fontfamily = 'serif', fontsize = 16)
ax2.set_ylim(-16, -21.5)
ax2.text(0.5, -20.5, '$R^2 = 0.22$', fontfamily = 'serif', fontsize = 19)
print("Mean squared error_color: %.2f" % mean_squared_error(Mcol,pred2))
print("R2 Score_color: %.2f" % r2_score(Mcol,pred2))
#%matplotlib notebook
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.22)
plt.show()
#fig.savefig(os.getcwd()+'/Hierchichal_analysis/SBF_Tripp.pdf',dpi = 500, bbox_inches='tight', pad_inches=0.2)
# Out:
# Mean squared error_st: 0.12
# R2 Score_st: 0.40
# Mean squared error_color: 0.12
# R2 Score_color: 0.23

# %%
#Hubble diagram
import matplotlib.gridspec as gridspec
H0full = 67.79
H0cut = 69.08
H0shoes = 72.84
os.chdir('/Users/krishna/Documents/phd_work/SNe_data_analy/checks/Hierchichal_analysis')

df_zcut = pd.read_csv('SBF_cosmo_zcut.csv')
dist_SBF = df_zcut['mu']
sig_mu = df_zcut['err_mu']
z_cut = df_zcut['redshift']


dfff = pd.read_csv('SBF_cosmo_full.csv')
df_full = dfff.loc[(dff['redshift'] < 0.02)]
mu_full = df_full['mu']
dmu_full = df_full['err_mu']
z_full = df_full['redshift']

plt.rc('font', family='serif')
plt.rcParams['axes.xmargin'] = 0
plt.rcParams['axes.ymargin'] = 0

def bestfit(h0, zs):
    return 5*np.log10(c*zs/h0*(1 + 1/2*(1- q0)*zs - 1/6*(1- q0 - 3*q0**2 + j0)*zs**2)) + 25

gs = gridspec.GridSpec(2, 1, height_ratios=[5, 1.5])
fig = plt.figure(figsize=(11, 8))
ax1 = plt.subplot(gs[0])

ax1.tick_params(axis='both',direction='in',labelsize=16)
ax1.xaxis.set_tick_params(which='major',width=1.5,length=7.5)
ax1.xaxis.set_tick_params(which='minor',width=1.5,length=4.5)
ax1.yaxis.set_tick_params(which='major',width=1.5,length=7.5)
ax1.yaxis.set_tick_params(which='minor',width=1.5,length=4.5)
ax1.spines['top'].set_linewidth(1.5)
ax1.spines['right'].set_linewidth(1.5)
ax1.spines['bottom'].set_linewidth(1.5)
ax1.spines['left'].set_linewidth(1.5)
ax1.xaxis.set_label_coords(0.5, -0.06)
ax1.tick_params(axis='both',direction='in',which='both')


ax1.errorbar(z_cut, dist_SBF, yerr=sig_mu, fmt='o', ms = 8, mfc = '#4292c6', mec = '#084594', ecolor = '#4292c6',
             elinewidth = 1, capsize =3, label = 'z-cut Sample')

ax1.errorbar(z_full, mu_full, yerr = dmu_full, fmt='o', ms = 8, mfc = '#4292c6', mec = '#084594', ecolor = '#4292c6'
             ,elinewidth = 1, capsize =3, alpha = 0.2, label = 'Full Sample')

x =  np.linspace(0., 0.085, 200)
yfit = bestfit(H0cut, x)
yfit2 = bestfit(H0shoes, x)
ax1.plot(x,yfit,color='black', lw = 1.2, label = r'$H_0 = 69.08$')
ax1.plot(x,yfit2,'--' ,color='black', lw = 1.2)
ax1.set_ylabel(r'$\mu$ (mag)',  fontfamily = 'serif', fontsize = 18)
ax1.set_ylim(27, 38.5)
ax1.get_xaxis().set_visible(False) # to remove the x tick labels
ax1.legend()

ax2 = plt.subplot(gs[1], sharex = ax1)

ax2.tick_params(axis='both',direction='in',labelsize=16)
ax2.xaxis.set_tick_params(which='major',width=1.5,length=7.5)
ax2.xaxis.set_tick_params(which='minor',width=1.5,length=4.5)
ax2.yaxis.set_tick_params(which='major',width=1.5,length=7.5)
ax2.yaxis.set_tick_params(which='minor',width=1.5,length=4.5)
ax2.spines['top'].set_linewidth(1.5)
ax2.spines['right'].set_linewidth(1.5)
ax2.spines['bottom'].set_linewidth(1.5)
ax2.spines['left'].set_linewidth(1.5)
ax2.xaxis.set_label_coords(0.5, -0.25)
ax2.tick_params(axis='both',direction='in',which='both')
plt.rc('font', family='serif')


model = bestfit(H0cut, z_cut)
model2 = bestfit(H0full, z_full)
diff = np.array(dist_SBF) - np.array(model)
diff2 = np.array(mu_full) - np.array(model2)

ax2.errorbar(z_cut, diff, yerr=sig_mu, fmt = 'o', ms = 8, mfc = '#4292c6', mec = '#084594', ecolor = '#4292c6',
              elinewidth = 1, capsize = 3)

ax2.errorbar(z_full, diff2, yerr=dmu_full, fmt = 'o', ms = 8, mfc = '#4292c6', mec = '#084594', ecolor = '#4292c6',
              elinewidth = 1, capsize = 3, alpha = 0.2)

ax2.plot(x, np.zeros_like(x), color = 'black', lw =1.2)
ax2.set_ylabel(r'$\Delta\mu$' , fontfamily = 'serif', fontsize = 16)
ax2.set_xlabel(r'redshift', fontfamily = 'serif', fontsize = 16)
ax2.set_ylim(-1.25 , 1.25)

plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.02)
plt.show()
fig.savefig("H01.pdf", dpi = 500, bbox_inches='tight', pad_inches=0.2)

print("R2 score : %.2f" % r2_score(dist_SBF, model))
print("Mean squared error: %.2f" % mean_squared_error(dist_SBF, model))
# Out:
# R2 score : 0.91
# Mean squared error: 0.04

# %%
#Hubble diagram as in TRGB paper
H0full = 67.79
H0cut = 69.08

os.chdir('/Users/krishna/Documents/phd_work/SNe_data_analy/checks/Hierchichal_analysis')

df_zcut = pd.read_csv('SBF_cosmo_zcut.csv')
dist_SBF = df_zcut['mu']
sig_mu = df_zcut['err_mu']
z_cut = df_zcut['redshift']


df_full = pd.read_csv('SBF_cosmo_full.csv')
mu_full = df_full['mu']
dmu_full = df_full['err_mu']
z_full = df_full['redshift']


def logczb(zz):
    return np.log10(c*zz*(1 + 1/2*(1- q0)*zz - 1/6*(1- q0 - 3*q0**2 + j0)*zz**2))

gs = gridspec.GridSpec(2, 1, height_ratios=[5, 1.5])
fig = plt.figure(figsize=(10, 8))
ax1 = plt.subplot(gs[0])
plt.rc('font', family='serif')
ax1.tick_params(axis='both',direction='in',labelsize=16)
ax1.xaxis.set_tick_params(which='major',width=1.5,length=7.5)
ax1.xaxis.set_tick_params(which='minor',width=1.5,length=4.5)
ax1.yaxis.set_tick_params(which='major',width=1.5,length=7.5)
ax1.yaxis.set_tick_params(which='minor',width=1.5,length=4.5)
ax1.spines['top'].set_linewidth(1.5)
ax1.spines['right'].set_linewidth(1.5)
ax1.spines['bottom'].set_linewidth(1.5)
ax1.spines['left'].set_linewidth(1.5)
ax1.xaxis.set_label_coords(0.5, -0.06)
ax1.tick_params(axis='both',direction='in',which='both')


xaxis = logczb(z_cut)
#xsbf = logczb(zSBF)
ax1.errorbar(xaxis, dist_SBF, fmt='o', ms = 8, mfc = '#4292c6', mec = '#084594')
#ax1.errorbar(xsbf, modsbf, fmt='o', ms = 8, mfc = '#e34a33', mec = '#b30000')
but = np.linspace(z_cut.min()-.002, z_cut.max()+.007, 200)
xx = logczb(but)
yyfit = bestfit(H0cut, but)
ax1.plot(xx, yyfit, color='black', lw = 1.5)
ax1.set_ylabel(r'$\mu$ (mag)',  fontfamily = 'serif', fontsize = 18)
#ax1.set_ylim(31.5,38.5)

# for i, txt in enumerate(SN_name):
#     ax1.annotate(txt, (xaxis[i], dist_SBF[i]), color = 'black', fontfamily = 'serif', fontsize = 8) 

ax2 = plt.subplot(gs[1], sharex = ax1)

ax2.tick_params(axis='both',direction='in',labelsize=16)
ax2.xaxis.set_tick_params(which='major',width=1.5,length=7.5)
ax2.xaxis.set_tick_params(which='minor',width=1.5,length=4.5)
ax2.yaxis.set_tick_params(which='major',width=1.5,length=7.5)
ax2.yaxis.set_tick_params(which='minor',width=1.5,length=4.5)
ax2.spines['top'].set_linewidth(1.5)
ax2.spines['right'].set_linewidth(1.5)
ax2.spines['bottom'].set_linewidth(1.5)
ax2.spines['left'].set_linewidth(1.5)
ax2.xaxis.set_label_coords(0.5, -0.3)
ax2.tick_params(axis='both',direction='in',which='both')


ax2.errorbar(xaxis, diff, yerr=sig_mu, fmt = 'o', ms = 8, mfc = '#4292c6', mec = '#084594', ecolor = '#4292c6',
              elinewidth = 1, capsize = 3)
ax2.plot(xx, np.zeros_like(xx), color = 'black', lw = 1.5)
ax2.set_xlabel(r'$\log cz(1 + \frac{1}{2}(1- q_0)z - \frac{1}{6}(1- q_0 - 3q_0^2 + j_0)z^2)$' 
               , fontfamily = 'serif', fontsize = 16)
ax2.set_ylabel(r'$\Delta\mu$' , fontfamily = 'serif', fontsize = 16)
ax2.set_ylim(-1.25 , 1.25)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.02)
plt.show()
#fig.savefig("H02.pdf", dpi = 500, bbox_inches='tight', pad_inches=0.2)

# %%
idata = az.from_pymc3(trace)  # model arg is not necessary but highly recommended
log_lik = idata.log_likelihood

idata.log_likelihood["log_lik_sum"] = log_lik.results0 + log_lik.results1

print(idata.log_likelihood["log_lik_sum"].shape)
#display(idata.log_likelihood["log_lik_sum"])

print(az.waic(idata, var_name="log_lik_sum", scale = 'log'))
